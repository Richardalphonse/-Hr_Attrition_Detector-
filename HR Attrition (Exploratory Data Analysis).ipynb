# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline

# %%
df= pd.read_csv('./WA_Fn-UseC_-HR-Employee-Attrition.csv')

# %%
df
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 0      41       Yes      Travel_Rarely       1102                   Sales
# 1      49        No  Travel_Frequently        279  Research & Development
# 2      37       Yes      Travel_Rarely       1373  Research & Development
# 3      33        No  Travel_Frequently       1392  Research & Development
# 4      27        No      Travel_Rarely        591  Research & Development
# ...   ...       ...                ...        ...                     ...
# 1465   36        No  Travel_Frequently        884  Research & Development
# 1466   39        No      Travel_Rarely        613  Research & Development
# 1467   27        No      Travel_Rarely        155  Research & Development
# 1468   49        No  Travel_Frequently       1023                   Sales
# 1469   34        No      Travel_Rarely        628  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  \
# ...

# %%
df.isnull().sum()
# Out:
# Age                         0
# Attrition                   0
# BusinessTravel              0
# DailyRate                   0
# Department                  0
# DistanceFromHome            0
# Education                   0
# EducationField              0
# EmployeeCount               0
# EmployeeNumber              0
# EnvironmentSatisfaction     0
# Gender                      0
# HourlyRate                  0
# JobInvolvement              0
# JobLevel                    0
# JobRole                     0
# JobSatisfaction             0
# MaritalStatus               0
# MonthlyIncome               0
# MonthlyRate                 0
# NumCompaniesWorked          0
# Over18                      0
# OverTime                    0
# PercentSalaryHike           0
# PerformanceRating           0
# RelationshipSatisfaction    0
# StandardHours               0
# StockOptionLevel            0
# TotalWorkingYears           0
# TrainingTimesLastYear       0
# WorkLifeBalance             0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   Attrition                 1470 non-null   object
#  2   BusinessTravel            1470 non-null   object
#  3   DailyRate                 1470 non-null   int64
#  4   Department                1470 non-null   object
#  5   DistanceFromHome          1470 non-null   int64
#  6   Education                 1470 non-null   int64
#  7   EducationField            1470 non-null   object
#  8   EmployeeCount             1470 non-null   int64
#  9   EmployeeNumber            1470 non-null   int64
#  10  EnvironmentSatisfaction   1470 non-null   int64
#  11  Gender                    1470 non-null   object
#  12  HourlyRate                1470 non-null   int64
#  13  JobInvolvement            1470 non-null   int64
# ...

# %%
df.describe()
# Out:
#                Age    DailyRate  DistanceFromHome    Education  EmployeeCount  \
# count  1470.000000  1470.000000       1470.000000  1470.000000         1470.0
# mean     36.923810   802.485714          9.192517     2.912925            1.0
# std       9.135373   403.509100          8.106864     1.024165            0.0
# min      18.000000   102.000000          1.000000     1.000000            1.0
# 25%      30.000000   465.000000          2.000000     2.000000            1.0
# 50%      36.000000   802.000000          7.000000     3.000000            1.0
# 75%      43.000000  1157.000000         14.000000     4.000000            1.0
# max      60.000000  1499.000000         29.000000     5.000000            1.0
#
#        EmployeeNumber  EnvironmentSatisfaction   HourlyRate  JobInvolvement  \
# count     1470.000000              1470.000000  1470.000000     1470.000000
# mean      1024.865306                 2.721769    65.891156        2.729932
# ...

# %%
sns.countplot(x=df.Attrition)
# Out:
# <AxesSubplot:xlabel='Attrition', ylabel='count'>

# %%
attrition_name= df.Attrition.value_counts().index
attrition_values= df.Attrition.value_counts().values
plt.rcParams['figure.figsize']=(12,6)
plt.pie(x=attrition_values,labels=attrition_name,autopct='%1.2f%%')
plt.show()

# %% [markdown]
# #### Observation:
# Based on the viualization of  Attrition rate in the dataset the ,the column has been imbalanced which weights around 84% for not leaving a job and around 16% for leaving a job

# %%
from sklearn.preprocessing import LabelEncoder
df['Attrition']= LabelEncoder().fit_transform(df['Attrition'])

# %%
sns.countplot(df.Department)
# Out:
# <AxesSubplot:xlabel='Department', ylabel='count'>

# %% [markdown]
# #### Observation:
# The distribution of employees based on the department varies into 'Sales','Research',''Human Resources'. Among the three departments ,the research & development counts the largest comparatively with others.

# %%
sns.countplot(df.EducationField)
# Out:
# <AxesSubplot:xlabel='EducationField', ylabel='count'>

# %% [markdown]
# #### Observation:
# The data has been distributed based on the education field of the employess. Among them the Life science and medical weights more than other department, the human resources takes a least postion.

# %%
sns.countplot(df.MaritalStatus)
# Out:
# <AxesSubplot:xlabel='MaritalStatus', ylabel='count'>

# %%
sns.countplot(df.Gender)
# Out:
# <AxesSubplot:xlabel='Gender', ylabel='count'>

# %% [markdown]
# #### Observation:
# Based on the vizualization the distribution of male employees in the dataset dominate the female employees, which will provide biased decision while building the model.

# %%
sns.scatterplot(x=df.MonthlyIncome,y=df.MonthlyRate,hue=df.Attrition)
plt.show()

# %% [markdown]
# #### Observation:
# As the salary of the employess increases the pepole leaving the company will be less compared to the people having higher salary.most of people decided to leave the company fall under the salary group between 2500-10000.

# %%
sns.scatterplot(x=df.Age,y=df.MonthlyIncome,hue=df.Attrition)
# Out:
# <AxesSubplot:xlabel='Age', ylabel='MonthlyIncome'>

# %% [markdown]
# #### observation :
# Through the above plot, we are able to understand  as age increases with respect to Income  has a linear relationship among them. At the same time the age group 20-30 has more attrition than the others. As younger the employees , they are able to switch for other choices irrespctive of other age groups.

# %%
sns.scatterplot(x=df.Age,y=df.WorkLifeBalance,hue=df.Attrition)
# Out:
# <AxesSubplot:xlabel='Age', ylabel='WorkLifeBalance'>

# %%
pd.set_option('display.max_rows',None)
pd.set_option('display.max_columns',None)
df.groupby(['Attrition','Age']).size().reset_index().sort_values(by='Age',ascending= False)
# Out:
#     Attrition  Age   0
# 42          0   60   5
# 41          0   59  10
# 40          0   58   9
# 81          1   58   5
# 39          0   57   4
# 38          0   56  11
# 80          1   56   3
# 37          0   55  19
# 79          1   55   3
# 36          0   54  18
# 78          1   53   2
# 35          0   53  17
# 77          1   52   3
# 34          0   52  15
# 76          1   51   2
# 33          0   51  17
# 75          1   50   5
# 32          0   50  25
# 74          1   49   2
# 31          0   49  22
# 73          1   48   2
# 30          0   48  17
# 72          1   47   3
# 29          0   47  21
# 28          0   46  29
# 71          1   46   4
# 70          1   45   2
# 27          0   45  39
# 26          0   44  27
# 69          1   44   6
# 25          0   43  30
# 68          1   43   2
# 67          1   42   2
# 24          0   42  44
# 23          0   41  34
# 66          1   41   6
# 65          1   40   5
# 22          0   40  52
# 64          1   39   6
# ...

# %%
sns.scatterplot(y=df.WorkLifeBalance,x=df.MonthlyIncome,hue=df.Attrition)
# Out:
# <AxesSubplot:xlabel='MonthlyIncome', ylabel='WorkLifeBalance'>

# %% [markdown]
# #### Observation:
# Through the following plot able to vizualize that worklife balance plays  a mojor role in terms of determining the attrition rate of the employees.As lower the range of worklife balance the attrition rate is higher compared with income of the employees.

# %%
sns.scatterplot(x=df.Age,y=df.TotalWorkingYears,hue=df.Attrition)
# Out:
# <AxesSubplot:xlabel='Age', ylabel='TotalWorkingYears'>

# %% [markdown]
# #### Observation;
#  As the age increases with respect to total works , the employees towards the attrition was very less ,while comparing with the less age people in their career choice. The elder people are risk averse in terms of switching the company.
